# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Sun Jun  7 17:10:33 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !unzip -q /content/data.zip -d /content/drive/MyDrive/Yolov8_Traffic_Counter/custom_data
# Out:
# replace /content/drive/MyDrive/Yolov8_Traffic_Counter/custom_data/classes.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !unzip -q /content/data.zip -d /content/drive/MyDrive/Indian_Traffic_Analysis_Yolo/

# %%
# !python yolov8_train_val_split.py
# Out:
# ✅ Split complete: 75 train, 9 val

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.1 MB/s eta 0:00:00
# ...

# %%
# Python function to automatically create data.yaml config file
# 1. Reads "classes.txt" file to get list of class names
# 2. Creates data dictionary with correct paths to folders, number of classes, and names of classes
# 3. Writes data in YAML format to data.yaml

import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': '/content/drive/MyDrive/Yolov8_Traffic_Counter/data',
      'train': 'images/train',
      'val': 'images/val',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = '/content/drive/MyDrive/Yolov8_Traffic_Counter/custom_data/classes.txt'
path_to_data_yaml = '/content/drive/MyDrive/Yolov8_Traffic_Counter/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat /content/drive/MyDrive/Yolov8_Traffic_Counter/data.yaml
# Out:
# Created config file at /content/drive/MyDrive/Yolov8_Traffic_Counter/data.yaml
#
# File contents:
#
# path: /content/drive/MyDrive/Yolov8_Traffic_Counter/data
# train: images/train
# val: images/val
# nc: 8
# names:
# - auto
# - bike
# - bus
# - car
# - cycle
# - rickshaw
# - taxi
# - truck

# %%
# !yolo detect train data=/content/drive/MyDrive/Yolov8_Traffic_Counter/data.yaml model=yolov8n.pt epochs=60
# Out:
# Ultralytics 8.4.61 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train-2/weights/best.pt source=/content/drive/MyDrive/Yolov8_Traffic_Counter/data/images/val save=True
# Out:
# Ultralytics 8.4.61 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/9 /content/drive/MyDrive/Yolov8_Traffic_Counter/data/images/val/0726f0fa-frame_0022.jpg: 640x384 2 cars, 2 trucks, 68.3ms
# image 2/9 /content/drive/MyDrive/Yolov8_Traffic_Counter/data/images/val/15c73db8-frame_0055.jpg: 640x384 (no detections), 8.3ms
# image 3/9 /content/drive/MyDrive/Yolov8_Traffic_Counter/data/images/val/3749ae3e-frame_0027.jpg: 640x384 1 car, 1 truck, 7.9ms
# image 4/9 /content/drive/MyDrive/Yolov8_Traffic_Counter/data/images/val/62fafdca-frame_0013.jpg: 640x384 (no detections), 7.4ms
# image 5/9 /content/drive/MyDrive/Yolov8_Traffic_Counter/data/images/val/79befb7e-frame_0031.jpg: 640x384 1 car, 2 trucks, 11.6ms
# image 6/9 /content/drive/MyDrive/Yolov8_Traffic_Counter/data/images/val/7f030d21-frame_0066.jpg: 640x384 1 rickshaw, 13.1ms
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Create "my_model" folder to store model weights and train results
#!mkdir /content/my_model
# !cp /content/runs/detect/train-2/weights/best.pt /content/my_model/my_yolov8_model.pt
# !cp -r /content/runs/detect/train-2 /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_yolov8_model.pt
# !zip -r /content/my_model.zip train-2
# %cd /content
# Out:
# /content/my_model
# updating: my_yolov8_model.pt (deflated 9%)
#   adding: train-2/ (stored 0%)
#   adding: train-2/val_batch0_labels.jpg (deflated 16%)
#   adding: train-2/confusion_matrix.png (deflated 29%)
#   adding: train-2/labels.jpg (deflated 32%)
#   adding: train-2/BoxR_curve.png (deflated 11%)
#   adding: train-2/train_batch251.jpg (deflated 11%)
#   adding: train-2/args.yaml (deflated 52%)
#   adding: train-2/BoxF1_curve.png (deflated 7%)
#   adding: train-2/BoxP_curve.png (deflated 11%)
#   adding: train-2/train_batch1.jpg (deflated 5%)
#   adding: train-2/confusion_matrix_normalized.png (deflated 26%)
#   adding: train-2/BoxPR_curve.png (deflated 19%)
#   adding: train-2/results.png (deflated 7%)
#   adding: train-2/weights/ (stored 0%)
#   adding: train-2/weights/last.pt (deflated 9%)
#   adding: train-2/weights/best.pt (deflated 9%)
#   adding: train-2/train_batch252.jpg (deflated 11%)
#   adding: train-2/train_batch0.jpg (deflated 6%)
# ...
